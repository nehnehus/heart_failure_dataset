# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #adding my libraies that i need to import from.

# %%
heart_failure = pd.read_csv('../Data/heart.csv')
df = pd.read_csv('../Data/heart_disease.csv')
heart_failure
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 0     56.0    Male           153.0              155.0            High     Yes
# 1     69.0  Female           146.0              286.0            High      No
# 2     46.0    Male           126.0              216.0             Low      No
# 3     32.0  Female           122.0              293.0            High     Yes
# 4     60.0    Male           166.0              242.0             Low     Yes
# ...    ...     ...             ...                ...             ...     ...
# 9995  25.0  Female           136.0              243.0          Medium     Yes
# 9996  38.0    Male           172.0              154.0          Medium      No
# 9997  73.0    Male           152.0              201.0            High     Yes
# 9998  23.0    Male           142.0              299.0             Low     Yes
# 9999  38.0  Female           128.0              193.0          Medium     Yes
#
# ...

# %% [markdown]
# #entering my two dataframes and viewing them.

# %%
heart_failure.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    str
#  2   ChestPainType   918 non-null    str
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    str
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    str
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    str
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), str(5)
# memory usage: 86.2 KB

# %% [markdown]
# #getting a summary of my heart_failure dataframe and Heart_disease dataframe

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   9971 non-null   float64
#  1   Gender                9981 non-null   str
#  2   Blood Pressure        9981 non-null   float64
#  3   Cholesterol Level     9970 non-null   float64
#  4   Exercise Habits       9975 non-null   str
#  5   Smoking               9975 non-null   str
#  6   Family Heart Disease  9979 non-null   str
#  7   Diabetes              9970 non-null   str
#  8   BMI                   9978 non-null   float64
#  9   High Blood Pressure   9974 non-null   str
#  10  Low HDL Cholesterol   9975 non-null   str
#  11  High LDL Cholesterol  9974 non-null   str
#  12  Alcohol Consumption   7414 non-null   str
#  13  Stress Level          9978 non-null   str
#  14  Sleep Hours           9975 non-null   float64
# ...

# %%
heart_failure.shape
# Out:
# (918, 12)

# %%
df.shape
# Out:
# (10000, 21)

# %% [markdown]
# #getting how many things exist under each axis of both my heart_failure dataframe  and heart_disease df

# %%
heart_failure.value_counts()
# Out:
# Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 40   M    ATA            140        289          0          Normal      172    N               0.0      Up        0               1
# 49   F    NAP            160        180          0          Normal      156    N               1.0      Flat      1               1
# 37   M    ATA            130        283          0          ST          98     N               0.0      Up        0               1
# 48   F    ASY            138        214          0          Normal      108    Y               1.5      Flat      1               1
# 54   M    NAP            150        195          0          Normal      122    N               0.0      Up        0               1
#                                                                                                                                  ..
# ...

# %% [markdown]
# #getting the counts of unique values in my heart_failure and heart_disease df columns

# %%
df.value_counts()
# Out:
# Age   Gender  Blood Pressure  Cholesterol Level  Exercise Habits  Smoking  Family Heart Disease  Diabetes  BMI        High Blood Pressure  Low HDL Cholesterol  High LDL Cholesterol  Alcohol Consumption  Stress Level  Sleep Hours  Sugar Consumption  Triglyceride Level  Fasting Blood Sugar  CRP Level  Homocysteine Level  Heart Disease Status
# 69.0  Female  146.0           286.0              High             No       Yes                   Yes       25.221799  No                   Yes                  No                    Medium               High          8.744034     Medium             133.0               157.0                9.355389   19.298875           No                      1
# ...

# %%
heart_failure.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.describe()
# Out:
#                Age  Blood Pressure  Cholesterol Level          BMI  \
# count  9971.000000     9981.000000        9970.000000  9978.000000
# mean     49.296259      149.757740         225.425577    29.077269
# std      18.193970       17.572969          43.575809     6.307098
# min      18.000000      120.000000         150.000000    18.002837
# 25%      34.000000      134.000000         187.000000    23.658075
# 50%      49.000000      150.000000         226.000000    29.079492
# 75%      65.000000      165.000000         263.000000    34.520015
# max      80.000000      180.000000         300.000000    39.996954
#
#        Sleep Hours  Triglyceride Level  Fasting Blood Sugar    CRP Level  \
# count  9975.000000         9974.000000          9978.000000  9974.000000
# mean      6.991329          250.734409           120.142213     7.472201
# std       1.753195           87.067226            23.584011     4.340248
# ...

# %% [markdown]
# #looking at the stats summary in both my heart_failure and heart_disease datasets.

# %%
high_chol = heart_failure.loc[heart_failure['Cholesterol'] > 240]
print(high_chol)
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 5     39   M           NAP        120          339          0     Normal
# 9     48   F           ATA        120          284          0     Normal
# 15    54   F           ATA        120          273          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 896   47   M           NAP        130          253          0     Normal
# 900   58   M           ASY        114          318          0         ST
# 906   55   F           ATA        132          342          0     Normal
# 912   57   F           ASY        140          241          0     Normal
# 913   45   M            TA        110          264          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
high_chol = df.loc[df['Cholesterol Level'] > 240]
print(high_chol)
# Out:
#        Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 1     69.0  Female           146.0              286.0            High      No
# 3     32.0  Female           122.0              293.0            High     Yes
# 4     60.0    Male           166.0              242.0             Low     Yes
# 5     25.0    Male           152.0              257.0             Low     Yes
# 8     56.0  Female           135.0              291.0             Low      No
# ...    ...     ...             ...                ...             ...     ...
# 9988  68.0    Male           157.0              292.0            High     Yes
# 9991  41.0  Female           160.0              241.0          Medium      No
# 9992  68.0  Female           169.0              291.0          Medium     Yes
# 9995  25.0  Female           136.0              243.0          Medium     Yes
# 9998  23.0    Male           142.0              299.0             Low     Yes
#
# ...

# %% [markdown]
# #filtering what data i want to look at with both my heart_failure and heart_disease dataframes.

# %%
disease_info = heart_failure.loc[heart_failure['HeartDisease'] == 1, ['Age', 'Sex']]
print(disease_info)
# Out:
#      Age Sex
# 1     49   F
# 3     48   F
# 8     37   M
# 11    58   M
# 13    49   M
# ..   ...  ..
# 912   57   F
# 913   45   M
# 914   68   M
# 915   57   M
# 916   57   F
#
# [508 rows x 2 columns]

# %%
disease_info = df.loc[df['Heart Disease Status'].str.lower() == 'yes', ['Age', 'Gender']]
print(disease_info)
# Out:
#        Age  Gender
# 8000  59.0  Female
# 8001  41.0    Male
# 8002  21.0    Male
# 8003  61.0    Male
# 8004  36.0    Male
# ...    ...     ...
# 9995  25.0  Female
# 9996  38.0    Male
# 9997  73.0    Male
# 9998  23.0    Male
# 9999  38.0  Female
#
# [2000 rows x 2 columns]

# %% [markdown]
# #had to use the above search in google to fix my issue, i was getting an empty dataframe error. i had to put yes instead of 1 in since it wasn't an integer and also i had to use the str.lower() incase it was an upper y it would still work, this fixed my issue.

# %%
heart_failure.loc[0:5, 'Age': 'Cholesterol']
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol
# 0   40   M           ATA        140          289
# 1   49   F           NAP        160          180
# 2   37   M           ATA        130          283
# 3   48   F           ASY        138          214
# 4   54   M           NAP        150          195
# 5   39   M           NAP        120          339

# %%
df.loc[0:5, 'Age': 'Cholesterol Level']
# Out:
#     Age  Gender  Blood Pressure  Cholesterol Level
# 0  56.0    Male           153.0              155.0
# 1  69.0  Female           146.0              286.0
# 2  46.0    Male           126.0              216.0
# 3  32.0  Female           122.0              293.0
# 4  60.0    Male           166.0              242.0
# 5  25.0    Male           152.0              257.0

# %% [markdown]
# #Looking at the rows and colums from age to cholesterol/cholestrol level.

# %%
subset = heart_failure.iloc[:, 0:3]
print(subset)
# Out:
#      Age Sex ChestPainType
# 0     40   M           ATA
# 1     49   F           NAP
# 2     37   M           ATA
# 3     48   F           ASY
# 4     54   M           NAP
# ..   ...  ..           ...
# 913   45   M            TA
# 914   68   M           ASY
# 915   57   M           ASY
# 916   57   F           ATA
# 917   38   M           NAP
#
# [918 rows x 3 columns]

# %%
subset_2 = df.iloc[:, 0:3]
print(subset_2)
# Out:
#        Age  Gender  Blood Pressure
# 0     56.0    Male           153.0
# 1     69.0  Female           146.0
# 2     46.0    Male           126.0
# 3     32.0  Female           122.0
# 4     60.0    Male           166.0
# ...    ...     ...             ...
# 9995  25.0  Female           136.0
# 9996  38.0    Male           172.0
# 9997  73.0    Male           152.0
# 9998  23.0    Male           142.0
# 9999  38.0  Female           128.0
#
# [10000 rows x 3 columns]

# %% [markdown]
# #slicing and filtering  rows and colums by the dataframes based on their index rather than names.

# %%
subset = heart_failure.iloc[10:20, 2:5]
print(subset)
# Out:
#    ChestPainType  RestingBP  Cholesterol
# 10           NAP        130          211
# 11           ATA        136          164
# 12           ATA        120          204
# 13           ASY        140          234
# 14           NAP        115          211
# 15           ATA        120          273
# 16           ASY        110          196
# 17           ATA        120          201
# 18           ASY        100          248
# 19           ATA        120          267

# %%
subset_2 = df.iloc[10:20, 2:5]
print(subset_2)
# Out:
#     Blood Pressure  Cholesterol Level Exercise Habits
# 10           179.0              191.0            High
# 11           134.0              296.0            High
# 12           143.0              215.0            High
# 13           134.0              191.0            High
# 14           150.0              187.0            High
# 15           133.0              290.0          Medium
# 16           173.0              255.0          Medium
# 17           133.0              245.0             Low
# 18           125.0              219.0          Medium
# 19           133.0              187.0            High

# %%
heart_failure['HeartDisease'].value_counts()
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
df['Family Heart Disease'].value_counts()
# Out:
# Family Heart Disease
# No     5004
# Yes    4975
# Name: count, dtype: int64

# %%
df['Heart Disease Status'].value_counts()
# Out:
# Heart Disease Status
# No     8000
# Yes    2000
# Name: count, dtype: int64

# %% [markdown]
# #Getting counts for heart disease on both datasets

# %%
sorted_heart_failure = heart_failure.sort_values(by=['Age', 'Sex'])
print(sorted_heart_failure.head())
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 208   28   M           ATA        130          132          0        LVH
# 170   29   M           ATA        120          243          0     Normal
# 219   29   M           ATA        140          263          0     Normal
# 829   29   M           ATA        130          204          0        LVH
# 215   30   F            TA        170          237          0         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 208    185              N      0.0       Up             0
# 170    160              N      0.0       Up             0
# 219    170              N      0.0       Up             0
# 829    202              N      0.0       Up             0
# 215    170              N      0.0       Up             0

# %%
sorted_heart_failure_2 = df.sort_values(by=['Age', 'Gender'])
print(sorted_heart_failure_2.head())
# Out:
#       Age  Gender  Blood Pressure  Cholesterol Level Exercise Habits Smoking  \
# 133  18.0  Female           175.0              159.0            High     Yes
# 353  18.0  Female           132.0              264.0             Low     Yes
# 619  18.0  Female           151.0              217.0            High     Yes
# 622  18.0  Female           157.0              193.0          Medium     Yes
# 633  18.0  Female           142.0              209.0            High     Yes
#
#     Family Heart Disease Diabetes        BMI High Blood Pressure  ...  \
# 133                  Yes       No  19.868543                 Yes  ...
# 353                  Yes       No  30.141824                 Yes  ...
# 619                   No       No  24.928967                  No  ...
# 622                   No       No  37.211661                 Yes  ...
# 633                   No      Yes  20.248705                 Yes  ...
#
#     High LDL Cholesterol Alcohol Consumption Stress Level Sleep Hours  \
# ...

# %%
heart_failure.rename({'FastingBS': 'Fasting_Blood_Sugar', 'RestingECG': 'RestingEKG'}, axis=1, inplace=True)
heart_failure.head(10)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  Fasting_Blood_Sugar  \
# 0   40   M           ATA        140          289                    0
# 1   49   F           NAP        160          180                    0
# 2   37   M           ATA        130          283                    0
# 3   48   F           ASY        138          214                    0
# 4   54   M           NAP        150          195                    0
# 5   39   M           NAP        120          339                    0
# 6   45   F           ATA        130          237                    0
# 7   54   M           ATA        110          208                    0
# 8   37   M           ASY        140          207                    0
# 9   48   F           ATA        120          284                    0
#
#   RestingEKG  MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0     Normal    172              N      0.0       Up             0
# ...

# %%
df.rename({'High Blood Pressure': 'High BP', 'Blood Pressure': 'BP', 'Fasting Blood Sugar' : 'Fasting BS'}, axis=1, inplace=True)
df.head(10)
# Out:
#     Age  Gender     BP  Cholesterol Level Exercise Habits Smoking  \
# 0  56.0    Male  153.0              155.0            High     Yes
# 1  69.0  Female  146.0              286.0            High      No
# 2  46.0    Male  126.0              216.0             Low      No
# 3  32.0  Female  122.0              293.0            High     Yes
# 4  60.0    Male  166.0              242.0             Low     Yes
# 5  25.0    Male  152.0              257.0             Low     Yes
# 6  78.0  Female  121.0              175.0            High     Yes
# 7  38.0  Female  161.0              187.0             Low     Yes
# 8  56.0  Female  135.0              291.0             Low      No
# 9  75.0    Male  144.0              252.0             Low     Yes
#
#   Family Heart Disease Diabetes        BMI High BP  ... High LDL Cholesterol  \
# 0                  Yes       No  24.991591     Yes  ...                   No
# 1                  Yes      Yes  25.221799      No  ...                   No
# ...

# %% [markdown]
# #Changed some names in the two datasets.

# %%
print(heart_failure.isnull().sum().sum())
# Out:
# 0

# %%
print(df.isnull().sum().sum())
# Out:
# 3054

# %%
rows_with_nulls = df[df.isna().any(axis=1)]
print(rows_with_nulls)
# Out:
#        Age  Gender     BP  Cholesterol Level Exercise Habits Smoking  \
# 0     56.0    Male  153.0              155.0            High     Yes
# 8     56.0  Female  135.0              291.0             Low      No
# 10    36.0  Female  179.0              191.0            High      No
# 11    40.0  Female  134.0              296.0            High      No
# 19    20.0  Female  133.0              187.0            High     Yes
# ...    ...     ...    ...                ...             ...     ...
# 9986  23.0    Male  147.0              292.0             Low      No
# 9991  41.0  Female  160.0              241.0          Medium      No
# 9993  27.0  Female  153.0              188.0          Medium      No
# 9996  38.0    Male  172.0              154.0          Medium      No
# 9997  73.0    Male  152.0              201.0            High     Yes
#
#      Family Heart Disease Diabetes        BMI High BP  ...  \
# 0                     Yes       No  24.991591     Yes  ...
# ...

# %% [markdown]
# #looking at the colums with null values

# %%
df = df.fillna('Unknown')
df
# Out:
#        Age  Gender     BP Cholesterol Level Exercise Habits Smoking  \
# 0     56.0    Male  153.0             155.0            High     Yes
# 1     69.0  Female  146.0             286.0            High      No
# 2     46.0    Male  126.0             216.0             Low      No
# 3     32.0  Female  122.0             293.0            High     Yes
# 4     60.0    Male  166.0             242.0             Low     Yes
# ...    ...     ...    ...               ...             ...     ...
# 9995  25.0  Female  136.0             243.0          Medium     Yes
# 9996  38.0    Male  172.0             154.0          Medium      No
# 9997  73.0    Male  152.0             201.0            High     Yes
# 9998  23.0    Male  142.0             299.0             Low     Yes
# 9999  38.0  Female  128.0             193.0          Medium     Yes
#
#      Family Heart Disease Diabetes        BMI High BP  ...  \
# 0                     Yes       No  24.991591     Yes  ...
# ...

# %% [markdown]
# #filled null values with unknown

# %% [markdown]
# #no null values in the heart_failure, but several in the heart_disease df.

# %%
print(heart_failure.duplicated().sum())
# Out:
# 0

# %%
print(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# #no duplicates in either df.

# %%
avg_heart_failure = heart_failure.groupby("RestingBP")['Cholesterol'].mean().sort_values(ascending=False)
avg_heart_failure
# Out:
# RestingBP
# 113    468.0
# 127    333.0
# 96     305.0
# 114    288.0
# 141    284.0
#        ...
# 131     73.5
# 80       0.0
# 0        0.0
# 95       0.0
# 185      0.0
# Name: Cholesterol, Length: 67, dtype: float64

# %%
print (df.dtypes)
# Out:
# Age                     object
# Gender                     str
# BP                      object
# Cholesterol Level       object
# Exercise Habits            str
# Smoking                    str
# Family Heart Disease       str
# Diabetes                   str
# BMI                     object
# High BP                    str
# Low HDL Cholesterol        str
# High LDL Cholesterol       str
# Alcohol Consumption        str
# Stress Level               str
# Sleep Hours             object
# Sugar Consumption          str
# Triglyceride Level      object
# Fasting BS              object
# CRP Level               object
# Homocysteine Level      object
# Heart Disease Status       str
# dtype: object

# %%
metrics = [
    'Age', 'Sleep Hours', 'Cholesterol Level', 'BMI', 'Fasting BS', 'CRP Level', 'Homocysteine Level', 'BP', 'Triglyceride Level'
]
for col in metrics:
    df[col] = pd.to_numeric(df[col], errors='coerce')
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age                   9971 non-null   float64
#  1   Gender                10000 non-null  str
#  2   BP                    9981 non-null   float64
#  3   Cholesterol Level     9970 non-null   float64
#  4   Exercise Habits       10000 non-null  str
#  5   Smoking               10000 non-null  str
#  6   Family Heart Disease  10000 non-null  str
#  7   Diabetes              10000 non-null  str
#  8   BMI                   9978 non-null   float64
#  9   High BP               10000 non-null  str
#  10  Low HDL Cholesterol   10000 non-null  str
#  11  High LDL Cholesterol  10000 non-null  str
#  12  Alcohol Consumption   10000 non-null  str
#  13  Stress Level          10000 non-null  str
#  14  Sleep Hours           9975 non-null   float64
# ...

# %% [markdown]
# #changed some of the dypes to float.They were previously listed as objects.

# %%
#Histogram chart of Cholesterol on heart_failure df
plt.figure(figsize=(10,6))
sns.histplot(heart_failure['Cholesterol'],bins=30, kde=True, color='green')
plt.title('Distribution for Cholesterol')
plt.xlabel('Cholesterol')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#Histogram chart of Cholesterol on heart_disease df
plt.figure(figsize=(10,6))
sns.histplot(df['Cholesterol Level'],bins=30, kde=True, color='green')
plt.title('Distribution for Cholesterol')
plt.xlabel('Cholesterol')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
#checking the value counts of heart disease on heart_failure df
target_counts = heart_failure['HeartDisease'].value_counts()
target_counts
# Out:
# HeartDisease
# 1    508
# 0    410
# Name: count, dtype: int64

# %%
#checking the value counts of heart disease on heart_disease df
target_counts = df['Heart Disease Status'].value_counts()
target_counts
# Out:
# Heart Disease Status
# No     8000
# Yes    2000
# Name: count, dtype: int64

# %%
#Comparing Heart Disease By the Gender(male, female)
comparison_data = heart_failure.groupby(['HeartDisease','Sex']).size().unstack()
comparison_data.plot(kind='bar', figsize=(8,6), color=['pink','lightblue'])
plt.xticks(rotation=0)
plt.ylabel("Patient Count", fontsize=12)
plt.title("Heart Disease Comparison by Gender")
plt.show()

# %%
#Comparing Heart Disease By the Gender(male, female)
comparison_data = df.groupby(['Heart Disease Status','Gender']).size().unstack()
comparison_data.plot(kind='bar', figsize=(8,6), color=['pink','lightblue'])
plt.xticks(rotation=0)
plt.ylabel("Patient Count", fontsize=12)
plt.title("Heart Disease Comparison by Gender")
plt.show()

# %%
#Comparison Between The Age and Maximum Heart Rate
heart_failure.plot(kind='scatter', x='Age', y='MaxHR', alpha=0.7, c='HeartDisease', cmap='coolwarm', figsize=(10,6))
plt.title('Relationship Between Age and Max Heart Rate')
plt.xlabel('Age(Years)')
plt.ylabel('Max Heart Rate')
plt.show()

# %%
#Comparison Between The Age and CRP Level
df.plot(kind='scatter', x='Age', y='CRP Level', alpha=0.7, c='Heart Disease Status', cmap='coolwarm', figsize=(10,6))
plt.title('Relationship Between Age and CRP Level')
plt.xlabel('Age(Years)')
plt.ylabel('CRP Level')
plt.show()
# Out:
# c:\Users\BECKY\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\plotting\_matplotlib\core.py:1388: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(
